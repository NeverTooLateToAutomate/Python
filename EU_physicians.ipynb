# %%
# https://ec.europa.eu/eurostat/web/products-datasets/product?code=tps00044
# https://ec.europa.eu/eurostat/web/products-datasets/product?code=sdg_03_10

# %%
import pandas as pd

# %%
df = pd.read_csv("https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?file=data/tps00044.tsv.gz", sep='\t')

# %%
df
# Out:
#    unit,wstatus,isco08,geo\time     2005      2006      2007      2008   \
# 0        P_HTHAB,PRACT,OC221,AL        :    115.08    114.70         :
# 1        P_HTHAB,PRACT,OC221,AT   431.68    444.96    453.49    459.56
# 2        P_HTHAB,PRACT,OC221,BE   287.07    288.59    290.50    292.07
# 3        P_HTHAB,PRACT,OC221,BG   364.01    364.80    364.01    360.13
# 4        P_HTHAB,PRACT,OC221,CH        :         :         :    381.74
# 5        P_HTHAB,PRACT,OC221,CY   257.19    248.66    270.03    276.14
# 6        P_HTHAB,PRACT,OC221,CZ   355.43    356.36    356.25    354.18
# 7        P_HTHAB,PRACT,OC221,DE   339.53    343.67    348.63    354.06
# 8        P_HTHAB,PRACT,OC221,DK   330.86    338.44    340.15    349.41
# 9        P_HTHAB,PRACT,OC221,EE  316.54 b   319.01    325.71    333.34
# 10       P_HTHAB,PRACT,OC221,ES   356.62    364.79    358.82    357.58
# 11       P_HTHAB,PRACT,OC221,FI   263.40    268.20    268.87    272.05
# ...

# %%
df.columns
# Out:
# Index(['unit,wstatus,isco08,geo\time', '2005 ', '2006 ', '2007 ', '2008 ',
#        '2009 ', '2010 ', '2011 ', '2012 ', '2013 ', '2014 ', '2015 ', '2016 '],
#       dtype='object')

# %%
df_life = pd.read_csv("https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?file=data/sdg_03_10.tsv.gz", sep='\t')

# %%
df_life
# Out:
#     unit,sex,age,geo\time   2000    2001   2002   2003   2004   2005   2006   \
# 0           YR,F,Y_LT1,AL      :       :      :      :      :      :      :
# 1           YR,F,Y_LT1,AT   81.2    81.7   81.7   81.5   82.1   82.2   82.8
# 2           YR,F,Y_LT1,BE   81.0    81.2   81.2   81.1   81.9   81.9   82.3
# 3           YR,F,Y_LT1,BG   75.0    75.4   75.5   75.9   76.2   76.2   76.3
# 4           YR,F,Y_LT1,CH   82.8    83.2   83.2   83.2   83.8   84.0   84.2
# 5           YR,F,Y_LT1,CY   80.1    81.4   81.0   81.2   81.8   80.8   82.0
# 6           YR,F,Y_LT1,CZ   78.5    78.5   78.7   78.6   79.1   79.2   79.9
# 7           YR,F,Y_LT1,DE   81.2    81.4   81.3   81.3   81.9   82.0   82.4
# 8           YR,F,Y_LT1,DK   79.2    79.3   79.4   79.8   80.2   80.5   80.7
# 9         YR,F,Y_LT1,EA18      :       :   82.0   81.9   82.6   82.7   83.2
# 10        YR,F,Y_LT1,EA19      :       :   82.0   81.9   82.6   82.6   83.1
# ...
